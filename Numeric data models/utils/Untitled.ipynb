# %%
import pandas as pd
import sys
pd.read_excel('../data/Crop_Calendar_Data.xlsx')
# Out:
#              Crop                        AgroEcological Zone  \
# 0             NaN                                        NaN
# 1    Wheat, durum  North West favorable areas and know Gharb
# 2    Wheat, durum           areas Chaouia, Doukkala and Abda
# 3    Wheat, durum    Area Western High Atlas, Haouz and Haha
# 4    Wheat, durum                                  East Zone
# ..            ...                                        ...
# 191     Coriander           areas Chaouia, Doukkala and Abda
# 192     Coriander    Area Western High Atlas, Haouz and Haha
# 193     Coriander                                  East Zone
# 194     Coriander                                Mountainous
# 195     Coriander               Saharan and presaharic areas
#
#                                Additional information Early Sowing Unnamed: 4  \
# 0                                                 NaN          Day      Month
# ...
